# %%
import pandas as pd
import requests
import gmaps
import random
import numpy as np
from citipy import citipy
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(-90.00,90.00,2000)
lngs = np.random.uniform(-180.00,180.00, 2000)
lats_lngs = zip(lats,lngs)
coordinates = list(lats_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 762

# %%
# Check
check_url = url + "&q=Dallas"
city_data_check = requests.get(check_url).json()
city_data_check
# Out:
# {'coord': {'lon': -96.7836, 'lat': 32.7668},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 83.88,
#   'feels_like': 89.28,
#   'temp_min': 79.7,
#   'temp_max': 87.46,
#   'pressure': 1014,
#   'humidity': 67},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 140},
#  'clouds': {'all': 40},
#  'dt': 1629077077,
#  'sys': {'type': 2,
#   'id': 2018848,
#   'country': 'US',
#   'sunrise': 1629028253,
#   'sunset': 1629076349},
#  'timezone': -18000,
#  'id': 4684904,
#  'name': 'Dallas',
#  'cod': 200}

# %%
#Retrieve data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print("------------------------------")

# Counters for 50 cities in 10 sets for the 500 total
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descript = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | evensk
# Processing Record 4 of Set 1 | saint-pierre
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | lagos
# Processing Record 7 of Set 1 | borba
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | clyde river
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | ossora
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | husavik
# Processing Record 21 of Set 1 | tucumcari
# Processing Record 22 of Set 1 | vostok
# Processing Record 23 of Set 1 | necochea
# Processing Record 24 of Set 1 | dingle
# Processing Record 25 of Set 1 | westport
# Processing Record 26 of Set 1 | geraldton
# Processing Record 27 of Set 1 | nargana
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | ostrovnoy
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | lamu
# Processing Record 32 of Set 1 | arlit
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | kahului
# Processing Record 37 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 1 | pisco
# Processing Record 39 of Set 1 | bonfim
# Processing Record 40 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | kiunga
# Processing Record 43 of Set 1 | salalah
# Processing Record 44 of Set 1 | kargasok
# Processing Record 45 of Set 1 | mokhsogollokh
# Processing Record 46 of Set 1 | viedma
# Processing Record 47 of Set 1 | narsaq
# Processing Record 48 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 1 | upernavik
# Processing Record 50 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | tanete
# Processing Record 3 of Set 2 | mahibadhoo
# Processing Record 4 of Set 2 | saint-joseph
# Processing Record 5 of Set 2 | dukat
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | taltal
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | oriximina
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | namatanai
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | radomsko
# Processing Record 14 of Set 2 | mirnyy
# Processing Record 15 of Set 2 | bonavista
# Processing Record 16 of Set 2 | norman wells
# Processing Record 17 of Set 2 | umea
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | azare
# Processing Record 20 of Set 2 | yerofey pavlovich
# Processing Record 21 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 2 | yangjiang
# Processing Record 23 of Set 2 | bohodukhiv
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | ruidoso
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | harper
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | brignoles
# Processing Record 31 of Set 2 | kodiak
# Processing Record 32 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 2 | inhambane
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | benalla
# Processing Record 36 of Set 2 | laramie
# Processing Record 37 of Set 2 | mehamn
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | laguna
# Processing Record 41 of Set 2 | choix
# Processing Record 42 of Set 2 | carauari
# Processing Record 43 of Set 2 | college
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | port hedland
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | eureka
# Processing Record 50 of Set 2 | coahuayana
# Processing Record 1 of Set 3 | urumqi
# Processing Record 2 of Set 3 | kloulklubed
# Processing Record 3 of Set 3 | ambanja
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | honningsvag
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | tual
# Processing Record 10 of Set 3 | asau
# Processing Record 11 of Set 3 | paysandu
# Processing Record 12 of Set 3 | vila velha
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | nuuk
# Processing Record 15 of Set 3 | egvekinot
# Processing Record 16 of Set 3 | mecca
# Processing Record 17 of Set 3 | mafinga
# Processing Record 18 of Set 3 | hashtrud
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | cabo san lucas
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | nizhyn
# Processing Record 23 of Set 3 | seoul
# Processing Record 24 of Set 3 | talara
# Processing Record 25 of Set 3 | botwood
# Processing Record 26 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 3 | illapel
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | khanpur
# Processing Record 30 of Set 3 | la palma
# Processing Record 31 of Set 3 | calafell
# Processing Record 32 of Set 3 | bredasdorp
# Processing Record 33 of Set 3 | herat
# Processing Record 34 of Set 3 | pacific grove
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | bandarbeyla
# Processing Record 38 of Set 3 | ahipara
# Processing Record 39 of Set 3 | kapoeta
# Processing Record 40 of Set 3 | qaracala
# Processing Record 41 of Set 3 | northam
# Processing Record 42 of Set 3 | rincon
# Processing Record 43 of Set 3 | porto nacional
# Processing Record 44 of Set 3 | hovd
# Processing Record 45 of Set 3 | naze
# Processing Record 46 of Set 3 | hobart
# Processing Record 47 of Set 3 | hami
# Processing Record 48 of Set 3 | karacakoy
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | kapaa
# Processing Record 1 of Set 4 | virginia beach
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | saint anthony
# Processing Record 4 of Set 4 | grindavik
# Processing Record 5 of Set 4 | cidreira
# Processing Record 6 of Set 4 | adrar
# Processing Record 7 of Set 4 | lorengau
# Processing Record 8 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | les cayes
# Processing Record 11 of Set 4 | hay river
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | bintulu
# Processing Record 14 of Set 4 | senno
# Processing Record 15 of Set 4 | puerto el triunfo
# Processing Record 16 of Set 4 | woodstock
# Processing Record 17 of Set 4 | fortuna
# Processing Record 18 of Set 4 | mpika
# Processing Record 19 of Set 4 | myitkyina
# Processing Record 20 of Set 4 | flin flon
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | oktyabrskiy
# Processing Record 23 of Set 4 | calama
# Processing Record 24 of Set 4 | cape town
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | gat
# Processing Record 27 of Set 4 | vanavara
# Processing Record 28 of Set 4 | sherghati
# Processing Record 29 of Set 4 | deniliquin
# Processing Record 30 of Set 4 | lawton
# Processing Record 31 of Set 4 | gull lake
# Processing Record 32 of Set 4 | dzaoudzi
# Processing Record 33 of Set 4 | castro
# Processing Record 34 of Set 4 | bahia blanca
# Processing Record 35 of Set 4 | tuktoyaktuk
# Processing Record 36 of Set 4 | iralaya
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | kidal
# Processing Record 39 of Set 4 | arraial do cabo
# Processing Record 40 of Set 4 | cabanas
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | huarmey
# Processing Record 43 of Set 4 | hithadhoo
# Processing Record 44 of Set 4 | bayburt
# Processing Record 45 of Set 4 | maridi
# Processing Record 46 of Set 4 | curup
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | pouebo
# Processing Record 49 of Set 4 | vizinga
# Processing Record 50 of Set 4 | santa barbara
# Processing Record 1 of Set 5 | vao
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | togul
# Processing Record 4 of Set 5 | linqing
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | nassau
# Processing Record 7 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 5 | tecoanapa
# Processing Record 9 of Set 5 | sorland
# Processing Record 10 of Set 5 | yala
# Processing Record 11 of Set 5 | presidencia roque saenz pena
# Processing Record 12 of Set 5 | pasighat
# Processing Record 13 of Set 5 | hilo
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 5 | puerto madryn
# Processing Record 17 of Set 5 | ambunti
# Processing Record 18 of Set 5 | aksay
# Processing Record 19 of Set 5 | kashi
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | thompson
# Processing Record 22 of Set 5 | cooma
# Processing Record 23 of Set 5 | sulangan
# Processing Record 24 of Set 5 | baykit
# Processing Record 25 of Set 5 | general roca
# Processing Record 26 of Set 5 | zhaotong
# Processing Record 27 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 5 | okhotsk
# Processing Record 29 of Set 5 | caravelas
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | nhulunbuy
# Processing Record 32 of Set 5 | hearst
# Processing Record 33 of Set 5 | natal
# Processing Record 34 of Set 5 | keti bandar
# Processing Record 35 of Set 5 | shieli
# Processing Record 36 of Set 5 | chagoda
# Processing Record 37 of Set 5 | olafsvik
# Processing Record 38 of Set 5 | kuala terengganu
# Processing Record 39 of Set 5 | kamina
# Processing Record 40 of Set 5 | maceio
# Processing Record 41 of Set 5 | ndende
# Processing Record 42 of Set 5 | fougamou
# Processing Record 43 of Set 5 | ogdensburg
# Processing Record 44 of Set 5 | huazolotitlan
# City not found. Skipping...
# Processing Record 45 of Set 5 | camacha
# Processing Record 46 of Set 5 | cuamba
# Processing Record 47 of Set 5 | broome
# Processing Record 48 of Set 5 | gebze
# Processing Record 49 of Set 5 | bloemfontein
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | nchelenge
# Processing Record 2 of Set 6 | kampot
# Processing Record 3 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 6 | guerrero negro
# Processing Record 5 of Set 6 | abashiri
# Processing Record 6 of Set 6 | verkhnevilyuysk
# Processing Record 7 of Set 6 | yulara
# Processing Record 8 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 6 | norrtalje
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | elat
# Processing Record 12 of Set 6 | yumen
# Processing Record 13 of Set 6 | nara
# Processing Record 14 of Set 6 | lasa
# Processing Record 15 of Set 6 | askiz
# Processing Record 16 of Set 6 | umba
# Processing Record 17 of Set 6 | praia
# Processing Record 18 of Set 6 | road town
# Processing Record 19 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | bumba
# Processing Record 22 of Set 6 | souillac
# Processing Record 23 of Set 6 | olga
# Processing Record 24 of Set 6 | chicama
# Processing Record 25 of Set 6 | grand-lahou
# Processing Record 26 of Set 6 | finnsnes
# Processing Record 27 of Set 6 | coihaique
# Processing Record 28 of Set 6 | boguchany
# Processing Record 29 of Set 6 | kamloops
# Processing Record 30 of Set 6 | slave lake
# Processing Record 31 of Set 6 | fushun
# Processing Record 32 of Set 6 | baculin
# Processing Record 33 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 6 | sarangani
# Processing Record 35 of Set 6 | sambava
# Processing Record 36 of Set 6 | trenggalek
# Processing Record 37 of Set 6 | lavrentiya
# Processing Record 38 of Set 6 | mantua
# Processing Record 39 of Set 6 | noumea
# Processing Record 40 of Set 6 | haines junction
# Processing Record 41 of Set 6 | sobolevo
# Processing Record 42 of Set 6 | chaohu
# Processing Record 43 of Set 6 | bari
# Processing Record 44 of Set 6 | kishtwar
# Processing Record 45 of Set 6 | dudinka
# Processing Record 46 of Set 6 | great falls
# Processing Record 47 of Set 6 | vitimskiy
# City not found. Skipping...
# Processing Record 48 of Set 6 | severo-kurilsk
# Processing Record 49 of Set 6 | kichera
# Processing Record 50 of Set 6 | pingzhuang
# Processing Record 1 of Set 7 | quatre cocos
# Processing Record 2 of Set 7 | pevek
# Processing Record 3 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 4 of Set 7 | mwinilunga
# Processing Record 5 of Set 7 | ruteng
# Processing Record 6 of Set 7 | chandrakona
# Processing Record 7 of Set 7 | berlevag
# Processing Record 8 of Set 7 | murska sobota
# Processing Record 9 of Set 7 | sao francisco
# Processing Record 10 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | victoria
# Processing Record 13 of Set 7 | aitape
# Processing Record 14 of Set 7 | astana
# Processing Record 15 of Set 7 | chokwe
# Processing Record 16 of Set 7 | guane
# Processing Record 17 of Set 7 | cabras
# Processing Record 18 of Set 7 | inirida
# Processing Record 19 of Set 7 | berga
# Processing Record 20 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | salina cruz
# Processing Record 24 of Set 7 | ampanihy
# Processing Record 25 of Set 7 | yuncheng
# Processing Record 26 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 27 of Set 7 | tarakan
# Processing Record 28 of Set 7 | itacare
# Processing Record 29 of Set 7 | nouadhibou
# Processing Record 30 of Set 7 | lokosovo
# Processing Record 31 of Set 7 | shirokiy
# Processing Record 32 of Set 7 | komsomolskiy
# Processing Record 33 of Set 7 | palaiokomi
# Processing Record 34 of Set 7 | aksu
# Processing Record 35 of Set 7 | sansai
# City not found. Skipping...
# Processing Record 36 of Set 7 | banda aceh
# Processing Record 37 of Set 7 | zastron
# Processing Record 38 of Set 7 | voykove
# Processing Record 39 of Set 7 | krasnokamensk
# Processing Record 40 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 41 of Set 7 | port-gentil
# Processing Record 42 of Set 7 | christchurch
# Processing Record 43 of Set 7 | sinnamary
# Processing Record 44 of Set 7 | mitsamiouli
# Processing Record 45 of Set 7 | peniche
# Processing Record 46 of Set 7 | anloga
# Processing Record 47 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 48 of Set 7 | kirkenes
# Processing Record 49 of Set 7 | jamestown
# Processing Record 50 of Set 7 | bubaque
# Processing Record 1 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 8 | aras
# Processing Record 3 of Set 8 | aklavik
# Processing Record 4 of Set 8 | buckeye
# Processing Record 5 of Set 8 | samana
# Processing Record 6 of Set 8 | phangnga
# Processing Record 7 of Set 8 | osecina
# Processing Record 8 of Set 8 | klyuchi
# Processing Record 9 of Set 8 | karratha
# Processing Record 10 of Set 8 | porto novo
# Processing Record 11 of Set 8 | portland
# Processing Record 12 of Set 8 | cururupu
# Processing Record 13 of Set 8 | luderitz
# Processing Record 14 of Set 8 | hamilton
# Processing Record 15 of Set 8 | san patricio
# Processing Record 16 of Set 8 | dmanisi
# Processing Record 17 of Set 8 | bath
# Processing Record 18 of Set 8 | parainen
# Processing Record 19 of Set 8 | biak
# Processing Record 20 of Set 8 | mamlyutka
# Processing Record 21 of Set 8 | athens
# Processing Record 22 of Set 8 | denpasar
# Processing Record 23 of Set 8 | mayumba
# Processing Record 24 of Set 8 | edd
# Processing Record 25 of Set 8 | antalaha
# Processing Record 26 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 27 of Set 8 | amos
# Processing Record 28 of Set 8 | alghero
# Processing Record 29 of Set 8 | koslan
# Processing Record 30 of Set 8 | fare
# Processing Record 31 of Set 8 | tura
# Processing Record 32 of Set 8 | half moon bay
# Processing Record 33 of Set 8 | sao joao da barra
# Processing Record 34 of Set 8 | pochutla
# Processing Record 35 of Set 8 | ketchikan
# Processing Record 36 of Set 8 | ilulissat
# Processing Record 37 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 8 | ponta do sol
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | puerto penasco
# Processing Record 41 of Set 8 | sungaipenuh
# Processing Record 42 of Set 8 | bull savanna
# Processing Record 43 of Set 8 | ixtapa
# Processing Record 44 of Set 8 | roma
# Processing Record 45 of Set 8 | kununurra
# Processing Record 46 of Set 8 | owase
# Processing Record 47 of Set 8 | kavaratti
# Processing Record 48 of Set 8 | umtata
# Processing Record 49 of Set 8 | havre-saint-pierre
# Processing Record 50 of Set 8 | talnakh
# Processing Record 1 of Set 9 | mount gambier
# Processing Record 2 of Set 9 | mount pleasant
# Processing Record 3 of Set 9 | matara
# Processing Record 4 of Set 9 | newport
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | sola
# Processing Record 7 of Set 9 | praia da vitoria
# Processing Record 8 of Set 9 | vila do maio
# Processing Record 9 of Set 9 | mokrousovo
# Processing Record 10 of Set 9 | plastun
# Processing Record 11 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 9 | tocantinopolis
# City not found. Skipping...
# Processing Record 13 of Set 9 | pobe
# Processing Record 14 of Set 9 | killarney
# Processing Record 15 of Set 9 | shar
# Processing Record 16 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 9 | sangar
# Processing Record 18 of Set 9 | merauke
# Processing Record 19 of Set 9 | lucapa
# Processing Record 20 of Set 9 | zilupe
# Processing Record 21 of Set 9 | taganak
# Processing Record 22 of Set 9 | port macquarie
# Processing Record 23 of Set 9 | bathsheba
# Processing Record 24 of Set 9 | hangu
# Processing Record 25 of Set 9 | vila franca do campo
# Processing Record 26 of Set 9 | lexington
# Processing Record 27 of Set 9 | awbari
# Processing Record 28 of Set 9 | polson
# Processing Record 29 of Set 9 | airai
# Processing Record 30 of Set 9 | siva
# Processing Record 31 of Set 9 | beringovskiy
# Processing Record 32 of Set 9 | koboko
# Processing Record 33 of Set 9 | kumluca
# Processing Record 34 of Set 9 | kedrovyy
# Processing Record 35 of Set 9 | heze
# Processing Record 36 of Set 9 | gizo
# Processing Record 37 of Set 9 | port hardy
# Processing Record 38 of Set 9 | sur
# Processing Record 39 of Set 9 | dingli
# Processing Record 40 of Set 9 | carutapera
# Processing Record 41 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 9 | touros
# Processing Record 43 of Set 9 | whitianga
# Processing Record 44 of Set 9 | sept-iles
# Processing Record 45 of Set 9 | saint combs
# City not found. Skipping...
# Processing Record 46 of Set 9 | chapais
# Processing Record 47 of Set 9 | pouso alegre
# Processing Record 48 of Set 9 | pangnirtung
# Processing Record 49 of Set 9 | jieshi
# Processing Record 50 of Set 9 | saint-louis
# Processing Record 1 of Set 10 | coquimbo
# Processing Record 2 of Set 10 | shakawe
# Processing Record 3 of Set 10 | itarantim
# Processing Record 4 of Set 10 | paamiut
# Processing Record 5 of Set 10 | mayor pablo lagerenza
# Processing Record 6 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 10 | tazovskiy
# Processing Record 8 of Set 10 | mayo
# Processing Record 9 of Set 10 | sayyan
# Processing Record 10 of Set 10 | poso
# Processing Record 11 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 12 of Set 10 | lebu
# Processing Record 13 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 10 | manaure
# Processing Record 15 of Set 10 | quang ngai
# Processing Record 16 of Set 10 | zhongxing
# Processing Record 17 of Set 10 | lloydminster
# Processing Record 18 of Set 10 | tomatlan
# Processing Record 19 of Set 10 | yendi
# Processing Record 20 of Set 10 | mildura
# Processing Record 21 of Set 10 | ewa beach
# Processing Record 22 of Set 10 | namibe
# Processing Record 23 of Set 10 | lata
# Processing Record 24 of Set 10 | van
# Processing Record 25 of Set 10 | zaterechnyy
# Processing Record 26 of Set 10 | tevriz
# Processing Record 27 of Set 10 | chateaubelair
# Processing Record 28 of Set 10 | wad madani
# Processing Record 29 of Set 10 | pierre
# Processing Record 30 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 31 of Set 10 | falmouth
# Processing Record 32 of Set 10 | guanare
# Processing Record 33 of Set 10 | aktau
# Processing Record 34 of Set 10 | sisimiut
# Processing Record 35 of Set 10 | thunder bay
# Processing Record 36 of Set 10 | belen
# Processing Record 37 of Set 10 | miraflores
# Processing Record 38 of Set 10 | dalianwan
# Processing Record 39 of Set 10 | manjacaze
# Processing Record 40 of Set 10 | lubango
# Processing Record 41 of Set 10 | tromso
# Processing Record 42 of Set 10 | nguru
# Processing Record 43 of Set 10 | korfovskiy
# Processing Record 44 of Set 10 | whitehorse
# Processing Record 45 of Set 10 | tevaitoa
# Processing Record 46 of Set 10 | luanda
# Processing Record 47 of Set 10 | mponela
# Processing Record 48 of Set 10 | kysyl-syr
# Processing Record 49 of Set 10 | live oak
# Processing Record 50 of Set 10 | rocha
# Processing Record 1 of Set 11 | comodoro rivadavia
# Processing Record 2 of Set 11 | letlhakane
# Processing Record 3 of Set 11 | henties bay
# Processing Record 4 of Set 11 | jacareacanga
# Processing Record 5 of Set 11 | naryan-mar
# Processing Record 6 of Set 11 | sandy bay
# Processing Record 7 of Set 11 | kulhudhuffushi
# Processing Record 8 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 11 | kaseda
# Processing Record 10 of Set 11 | barcelos
# Processing Record 11 of Set 11 | lubana
# Processing Record 12 of Set 11 | suseni
# Processing Record 13 of Set 11 | jatoi
# City not found. Skipping...
# Processing Record 14 of Set 11 | zharkent
# Processing Record 15 of Set 11 | honiara
# Processing Record 16 of Set 11 | zyryanka
# Processing Record 17 of Set 11 | san vicente
# Processing Record 18 of Set 11 | coxim
# Processing Record 19 of Set 11 | udachnyy
# Processing Record 20 of Set 11 | helong
# Processing Record 21 of Set 11 | matagami
# Processing Record 22 of Set 11 | linchuan
# City not found. Skipping...
# Processing Record 23 of Set 11 | krasnyy yar
# Processing Record 24 of Set 11 | krasnoselkup
# Processing Record 25 of Set 11 | ugoofaaru
# Processing Record 26 of Set 11 | jamsa
# Processing Record 27 of Set 11 | vestmannaeyjar
# Processing Record 28 of Set 11 | banjar
# Processing Record 29 of Set 11 | tocopilla
# Processing Record 30 of Set 11 | tezu
# Processing Record 31 of Set 11 | balkhash
# Processing Record 32 of Set 11 | palmer
# Processing Record 33 of Set 11 | pemangkat
# Processing Record 34 of Set 11 | nkowakowa
# Processing Record 35 of Set 11 | saint-pie
# Processing Record 36 of Set 11 | victor harbor
# Processing Record 37 of Set 11 | alibag
# Processing Record 38 of Set 11 | verkhnyaya inta
# Processing Record 39 of Set 11 | gidam
# Processing Record 40 of Set 11 | mnogovershinnyy
# Processing Record 41 of Set 11 | nome
# Processing Record 42 of Set 11 | baoqing
# Processing Record 43 of Set 11 | west bay
# Processing Record 44 of Set 11 | nanortalik
# Processing Record 45 of Set 11 | djang
# City not found. Skipping...
# Processing Record 46 of Set 11 | uzyn
# Processing Record 47 of Set 11 | galesong
# Processing Record 48 of Set 11 | batagay-alyta
# Processing Record 49 of Set 11 | puerto escondido
# Processing Record 50 of Set 11 | samarai
# Processing Record 1 of Set 12 | kefamenanu
# Processing Record 2 of Set 12 | port-cartier
# Processing Record 3 of Set 12 | muisne
# Processing Record 4 of Set 12 | jining
# Processing Record 5 of Set 12 | qandala
# Processing Record 6 of Set 12 | azad shahr
# Processing Record 7 of Set 12 | sawakin
# Processing Record 8 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 9 of Set 12 | razole
# Processing Record 10 of Set 12 | sao felix do xingu
# Processing Record 11 of Set 12 | fort nelson
# Processing Record 12 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 12 | gubkinskiy
# Processing Record 14 of Set 12 | naifaru
# Processing Record 15 of Set 12 | nampula
# Processing Record 16 of Set 12 | ganzhou
# Processing Record 17 of Set 12 | kieta
# Processing Record 18 of Set 12 | ryotsu
# Processing Record 19 of Set 12 | jogighopa
# Processing Record 20 of Set 12 | saint-francois
# Processing Record 21 of Set 12 | dickinson
# Processing Record 22 of Set 12 | timmins
# Processing Record 23 of Set 12 | diffa
# Processing Record 24 of Set 12 | khabary
# Processing Record 25 of Set 12 | matay
# Processing Record 26 of Set 12 | quimperle
# Processing Record 27 of Set 12 | kushiro
# Processing Record 28 of Set 12 | kalabo
# Processing Record 29 of Set 12 | podyuga
# Processing Record 30 of Set 12 | rapid valley
# Processing Record 31 of Set 12 | sergeyevka
# Processing Record 32 of Set 12 | tartki
# City not found. Skipping...
# Processing Record 33 of Set 12 | mendoza
# Processing Record 34 of Set 12 | ponta delgada
# Processing Record 35 of Set 12 | tornio
# Processing Record 36 of Set 12 | faya
# Processing Record 37 of Set 12 | hudiksvall
# Processing Record 38 of Set 12 | alofi
# Processing Record 39 of Set 12 | hambantota
# Processing Record 40 of Set 12 | san cristobal
# Processing Record 41 of Set 12 | macamic
# Processing Record 42 of Set 12 | butembo
# Processing Record 43 of Set 12 | kudahuvadhoo
# Processing Record 44 of Set 12 | khromtau
# Processing Record 45 of Set 12 | alice springs
# Processing Record 46 of Set 12 | rossland
# Processing Record 47 of Set 12 | prainha
# Processing Record 48 of Set 12 | kardymovo
# Processing Record 49 of Set 12 | maragogi
# Processing Record 50 of Set 12 | glendive
# Processing Record 1 of Set 13 | prince rupert
# Processing Record 2 of Set 13 | tibati
# Processing Record 3 of Set 13 | belokurikha
# Processing Record 4 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 5 of Set 13 | cortez
# Processing Record 6 of Set 13 | san quintin
# Processing Record 7 of Set 13 | borogontsy
# Processing Record 8 of Set 13 | kimbe
# Processing Record 9 of Set 13 | nicoya
# Processing Record 10 of Set 13 | caarapo
# Processing Record 11 of Set 13 | ust-kuyga
# Processing Record 12 of Set 13 | moissac
# Processing Record 13 of Set 13 | srednekolymsk
# Processing Record 14 of Set 13 | nefteyugansk
# Processing Record 15 of Set 13 | kruisfontein
# Processing Record 16 of Set 13 | muli
# Processing Record 17 of Set 13 | okha
# Processing Record 18 of Set 13 | verkhnyaya toyma
# Processing Record 19 of Set 13 | kochevo
# Processing Record 20 of Set 13 | bairiki
# Processing Record 21 of Set 13 | kodinar
# Processing Record 22 of Set 13 | lanzhou
# Processing Record 23 of Set 13 | meulaboh
# Processing Record 24 of Set 13 | latung
# Processing Record 25 of Set 13 | changde
# Processing Record 26 of Set 13 | nuevo progreso
# Processing Record 27 of Set 13 | luang prabang
# Processing Record 28 of Set 13 | fairbanks
# Processing Record 29 of Set 13 | guiglo
# Processing Record 30 of Set 13 | roebourne
# Processing Record 31 of Set 13 | najran
# Processing Record 32 of Set 13 | morgaushi
# Processing Record 33 of Set 13 | kurilsk
# Processing Record 34 of Set 13 | pilar
# Processing Record 35 of Set 13 | jiwani
# Processing Record 36 of Set 13 | carrollton
# Processing Record 37 of Set 13 | zhanaozen
# Processing Record 38 of Set 13 | andros town
# Processing Record 39 of Set 13 | ginda
# Processing Record 40 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 41 of Set 13 | makushino
# Processing Record 42 of Set 13 | mackay
# Processing Record 43 of Set 13 | north bend
# Processing Record 44 of Set 13 | copiapo
# Processing Record 45 of Set 13 | the valley
# Processing Record 46 of Set 13 | kibre mengist
# Processing Record 47 of Set 13 | santa cruz
# Processing Record 48 of Set 13 | guanagazapa
# Processing Record 49 of Set 13 | florianopolis
# Processing Record 50 of Set 13 | jibuti
# Processing Record 1 of Set 14 | pangai
# Processing Record 2 of Set 14 | bowen
# Processing Record 3 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 4 of Set 14 | flinders
# Processing Record 5 of Set 14 | agva
# City not found. Skipping...
# Processing Record 6 of Set 14 | le marin
# Processing Record 7 of Set 14 | krasnokumskoye
# Processing Record 8 of Set 14 | camopi
# Processing Record 9 of Set 14 | leningradskiy
# Processing Record 10 of Set 14 | charlestown
# Processing Record 11 of Set 14 | jiuquan
# Processing Record 12 of Set 14 | mahanoro
# Processing Record 13 of Set 14 | tateyama
# Processing Record 14 of Set 14 | cabra
# Processing Record 15 of Set 14 | svetlogorsk
# Processing Record 16 of Set 14 | vaitape
# Processing Record 17 of Set 14 | talcahuano
# Processing Record 18 of Set 14 | emerald
# Processing Record 19 of Set 14 | bambanglipuro
# Processing Record 20 of Set 14 | pasni
# Processing Record 21 of Set 14 | krasnovishersk
# Processing Record 22 of Set 14 | grand gaube
# Processing Record 23 of Set 14 | saint-augustin
# Processing Record 24 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 14 | kjopsvik
# Processing Record 26 of Set 14 | kananga
# Processing Record 27 of Set 14 | raudeberg
# Processing Record 28 of Set 14 | bontang
# Processing Record 29 of Set 14 | sibu
# Processing Record 30 of Set 14 | ancud
# Processing Record 31 of Set 14 | sebinkarahisar
# Processing Record 32 of Set 14 | san carlos del zulia
# Processing Record 33 of Set 14 | mukhen
# Processing Record 34 of Set 14 | azrow
# City not found. Skipping...
# Processing Record 35 of Set 14 | dwarka
# Processing Record 36 of Set 14 | jiutai
# Processing Record 37 of Set 14 | luena
# Processing Record 38 of Set 14 | khvorostyanka
# Processing Record 39 of Set 14 | yerakion
# Processing Record 40 of Set 14 | siderno
# Processing Record 41 of Set 14 | sekoma
# Processing Record 42 of Set 14 | lydenburg
# Processing Record 43 of Set 14 | ati
# Processing Record 44 of Set 14 | sehithwa
# Processing Record 45 of Set 14 | parana
# Processing Record 46 of Set 14 | salinopolis
# Processing Record 47 of Set 14 | deputatskiy
# Processing Record 48 of Set 14 | abrau-dyurso
# Processing Record 49 of Set 14 | gualeguay
# Processing Record 50 of Set 14 | catole do rocha
# Processing Record 1 of Set 15 | kurchum
# Processing Record 2 of Set 15 | nouakchott
# Processing Record 3 of Set 15 | durban
# Processing Record 4 of Set 15 | buraydah
# Processing Record 5 of Set 15 | laibin
# Processing Record 6 of Set 15 | makasar
# Processing Record 7 of Set 15 | le port
# Processing Record 8 of Set 15 | banfora
# Processing Record 9 of Set 15 | dalby
# Processing Record 10 of Set 15 | inongo
# Processing Record 11 of Set 15 | carballo
# Processing Record 12 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 13 of Set 15 | rudnichnyy
# Processing Record 14 of Set 15 | nemuro
# Processing Record 15 of Set 15 | kyren
# Processing Record 16 of Set 15 | arona
# Processing Record 17 of Set 15 | qingdao
# Processing Record 18 of Set 15 | santarem
# Processing Record 19 of Set 15 | opuwo
# Processing Record 20 of Set 15 | tuatapere
# Processing Record 21 of Set 15 | pacifica
# Processing Record 22 of Set 15 | marsh harbour
# Processing Record 23 of Set 15 | kericho
# Processing Record 24 of Set 15 | coos bay
# Processing Record 25 of Set 15 | kakching
# Processing Record 26 of Set 15 | innisfail
# Processing Record 27 of Set 15 | igarka
# Processing Record 28 of Set 15 | waingapu
# Processing Record 29 of Set 15 | pingdingshan
# Processing Record 30 of Set 15 | malindi
# Processing Record 31 of Set 15 | north branch
# Processing Record 32 of Set 15 | tayu
# Processing Record 33 of Set 15 | havoysund
# Processing Record 34 of Set 15 | san matias
# Processing Record 35 of Set 15 | bom jesus
# Processing Record 36 of Set 15 | cayenne
# Processing Record 37 of Set 15 | methoni
# Processing Record 38 of Set 15 | aguimes
# Processing Record 39 of Set 15 | bogorodskoye
# Processing Record 40 of Set 15 | wewak
# Processing Record 41 of Set 15 | rolla
# Processing Record 42 of Set 15 | parasia
# Processing Record 43 of Set 15 | poum
# Processing Record 44 of Set 15 | zuenoula
# Processing Record 45 of Set 15 | mamallapuram
# Processing Record 46 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 15 | san jose de guanipa
# Processing Record 48 of Set 15 | finschhafen
# Processing Record 49 of Set 15 | ulaangom
# Processing Record 50 of Set 15 | salo
# Processing Record 1 of Set 16 | pudozh
# Processing Record 2 of Set 16 | diamantino
# Processing Record 3 of Set 16 | korgen
# Processing Record 4 of Set 16 | sokoni
# Processing Record 5 of Set 16 | am timan
# Processing Record 6 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 16 | qingyuan
# Processing Record 8 of Set 16 | maun
# Processing Record 9 of Set 16 | arkhangelsk
# Processing Record 10 of Set 16 | goderich
# Processing Record 11 of Set 16 | beaune
# Processing Record 12 of Set 16 | san isidro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame
cities_df = pd.DataFrame(city_data)
cities_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Albany      US  42.6001  -73.9662     66.02        80         100
# 1     Busselton      AU -33.6500  115.3333     59.04        63           0
# 2        Evensk      RU  61.9500  159.2333     55.85        75          41
# 3  Saint-Pierre      RE -21.3393   55.4781     65.84        82          75
# 4       Rikitea      PF -23.1203 -134.9692     74.82        75           0
# 5         Lagos      NG   6.5833    3.7500     77.32        86         100
# 6         Borba      BR  -4.3878  -59.5939     77.68        72          77
# 7   Yellowknife      CA  62.4560 -114.3525     61.32        67          75
# 8   Clyde River      CA  70.4692  -68.5914     43.70        79          95
# 9      Saldanha      ZA -33.0117   17.9442     51.85        66          11
#
#    Wind Speed       Description
# 0        3.15   overcast clouds
# 1       10.76         clear sky
# 2        9.66  scattered clouds
# 3        9.22     broken clouds
# 4       12.82         clear sky
# 5        5.28   overcast clouds
# 6        2.33     broken clouds
# 7       14.97     broken clouds
# 8        1.05   overcast clouds
# 9       11.77        few clouds

# %%
# Export data to a 
output_data_file = 'WeatherPy_Database.csv'
cities_df.to_csv(output_data_file,index_label='City_ID')
